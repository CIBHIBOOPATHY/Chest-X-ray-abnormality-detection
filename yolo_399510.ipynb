# %% [markdown]
# Installing requirements for YOLOv8 model

# %%
# !pip install ultralytics

# %% [markdown]
# Training the model

# %%
# !time yolo task=detect mode=train model=yolov8s.pt data="/kaggle/input/configuration600/yolov8_configuration.yaml" epochs=300 imgsz=640 batch=16 cache

# %% [markdown]
# Testing the model

# %%
# !time yolo task=detect mode=predict model="/kaggle/working/runs/detect/train3/weights/best.pt" source="/kaggle/input/yolodataframe600/Test/Test/images" imgsz=640 batch=16 cache conf=0.3 save_txt=True save_conf=True exist_ok=True
